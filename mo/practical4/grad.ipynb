# %%
import numdifftools as nd
import numpy as np
import itertools

# %%
def F(x):
    x_1 = x[0]
    x_2 = x[1]
    return 10 * x_1 ** 2 + x_2 ** 2

# %%
def gradient_fall(x_0 = (0.5, 1), e = 0.1, e_1 = 0.1, e_2 = 0.15, M = 10):
    N = 0
    step = 0
    t = [0]
    while True:
        if step != 7:
            if step != 3:
                k = 0
            grad = nd.Gradient(F)(x_0[k])
            norm = np.linalg.norm(np.array(grad))
            if norm < e_1:
                x_res = x_0[k]
                break
            if k >= M:
                x_res = x_0[k]
                break
            try:
                if len(t) < 2:
                    t[k] = 0.5
                else:
                    t[k] = t[k-1]
            except:
                t.append(t[k-1])
        try:
            x_0[k + 1] = (np.array(x_0[k]) - t[k] * np.array(grad))
        except IndexError:
            x_0.append(np.array(x_0[k]) - t[k] * np.array(grad))
        f_k_1 = F(x_0[k+1])
        f_k = F(x_0[k])
        N += 2
        if f_k_1 - f_k < 0 or f_k_1 - f_k < -e * norm * norm: # or f_k_1 - f_k < -e * norm * norm
            step = 9
        else:
            t[k] = t[k]/2
            step = 7
            continue
        norm_x = np.linalg.norm(np.array(x_0[k+1]) - np.array(x_0[k]))
        abs_f_x = abs(F(x_0[k+1]) - F(x_0[k]))
        norm_x_1 = np.linalg.norm(np.array(x_0[k]) - np.array(x_0[k-1]))
        abs_f_x_1 = abs(F(x_0[k]) - F(x_0[k-1]))
        N += 4
        if norm_x < e_2 and abs_f_x < e_2 and abs_f_x_1 < e_2 and norm_x_1 < e_2:
            x_res = x_0[k+1]
            break
        else:
            k += 1
            step = 3
    return x_res, N

# %%
true_x = (0, 0)
true_f_x = 0

x = [[[0.5, 1]], [[20, 40]]]
e1 = [0.1, 0.00001]
e2 = [0.1, 0.9]
e3 = [0.15, 0.9]
m = [10, 2]

for x_0, e, e_1, e_2, M in itertools.product(x, e1, e2, e3, m):
    print(f"Истинный минимум в x = {true_x}, f(x) = {true_f_x}")
    print(f"При параметрах x_0 = {x_0}, e = {e}, e_1 = {e_1}, e_2 = {e_2}, M = {M}")
    x, N = gradient_fall(x_0 = x_0, e = e, e_1 = e_1, e_2 = e_2, M = M)
    f_x = F(x)
    print(f"Минимум алгоритма в x = {x}, f(x) = {f_x}\nКоличество операций: {N}\nОтклонение +-{abs(true_f_x - f_x)}\n")
# Out:
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[0.5, 1]], e = 0.1, e_1 = 0.1, e_2 = 0.15, M = 10
# Минимум алгоритма в x = [0.00195313 0.58618164], f(x) = 0.3436470627784729
# Количество операций: 30
# Отклонение +-0.3436470627784729
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[0.5, 1], array([-0.125,  0.875]), array([0.03125 , 0.765625]), array([-0.0078125 ,  0.66992188]), array([0.00195313, 0.58618164])], e = 0.1, e_1 = 0.1, e_2 = 0.15, M = 2
# Минимум алгоритма в x = [0.03125  0.765625], f(x) = 0.5959472656249999
# Количество операций: 18
# Отклонение +-0.5959472656249999
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[0.5, 1], array([-0.125,  0.875]), array([0.03125 , 0.765625]), array([-0.0078125 ,  0.66992188]), array([0.00195313, 0.58618164])], e = 0.1, e_1 = 0.1, e_2 = 0.9, M = 10
# Минимум алгоритма в x = [-0.0078125   0.66992188], f(x) = 0.4494056701660156
# Количество операций: 24
# Отклонение +-0.4494056701660156
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[0.5, 1], array([-0.125,  0.875]), array([0.03125 , 0.765625]), array([-0.0078125 ,  0.66992188]), array([0.00195313, 0.58618164])], e = 0.1, e_1 = 0.1, e_2 = 0.9, M = 2
# Минимум алгоритма в x = [0.03125  0.765625], f(x) = 0.5959472656249999
# Количество операций: 18
# Отклонение +-0.5959472656249999
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[0.5, 1], array([-0.125,  0.875]), array([0.03125 , 0.765625]), array([-0.0078125 ,  0.66992188]), array([0.00195313, 0.58618164])], e = 0.1, e_1 = 0.9, e_2 = 0.15, M = 10
# Минимум алгоритма в x = [0.00195313 0.58618164], f(x) = 0.3436470627784729
# Количество операций: 30
# Отклонение +-0.3436470627784729
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[0.5, 1], array([-0.125,  0.875]), array([0.03125 , 0.765625]), array([-0.0078125 ,  0.66992188]), array([0.00195313, 0.58618164])], e = 0.1, e_1 = 0.9, e_2 = 0.15, M = 2
# Минимум алгоритма в x = [0.03125  0.765625], f(x) = 0.5959472656249999
# Количество операций: 18
# Отклонение +-0.5959472656249999
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[0.5, 1], array([-0.125,  0.875]), array([0.03125 , 0.765625]), array([-0.0078125 ,  0.66992188]), array([0.00195313, 0.58618164])], e = 0.1, e_1 = 0.9, e_2 = 0.9, M = 10
# Минимум алгоритма в x = [-0.0078125   0.66992188], f(x) = 0.4494056701660156
# Количество операций: 24
# Отклонение +-0.4494056701660156
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[0.5, 1], array([-0.125,  0.875]), array([0.03125 , 0.765625]), array([-0.0078125 ,  0.66992188]), array([0.00195313, 0.58618164])], e = 0.1, e_1 = 0.9, e_2 = 0.9, M = 2
# Минимум алгоритма в x = [0.03125  0.765625], f(x) = 0.5959472656249999
# Количество операций: 18
# Отклонение +-0.5959472656249999
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[0.5, 1], array([-0.125,  0.875]), array([0.03125 , 0.765625]), array([-0.0078125 ,  0.66992188]), array([0.00195313, 0.58618164])], e = 1e-05, e_1 = 0.1, e_2 = 0.15, M = 10
# Минимум алгоритма в x = [0.00195313 0.58618164], f(x) = 0.3436470627784729
# Количество операций: 30
# Отклонение +-0.3436470627784729
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[0.5, 1], array([-0.125,  0.875]), array([0.03125 , 0.765625]), array([-0.0078125 ,  0.66992188]), array([0.00195313, 0.58618164])], e = 1e-05, e_1 = 0.1, e_2 = 0.15, M = 2
# Минимум алгоритма в x = [0.03125  0.765625], f(x) = 0.5959472656249999
# Количество операций: 18
# Отклонение +-0.5959472656249999
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[0.5, 1], array([-0.125,  0.875]), array([0.03125 , 0.765625]), array([-0.0078125 ,  0.66992188]), array([0.00195313, 0.58618164])], e = 1e-05, e_1 = 0.1, e_2 = 0.9, M = 10
# Минимум алгоритма в x = [-0.0078125   0.66992188], f(x) = 0.4494056701660156
# Количество операций: 24
# Отклонение +-0.4494056701660156
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[0.5, 1], array([-0.125,  0.875]), array([0.03125 , 0.765625]), array([-0.0078125 ,  0.66992188]), array([0.00195313, 0.58618164])], e = 1e-05, e_1 = 0.1, e_2 = 0.9, M = 2
# Минимум алгоритма в x = [0.03125  0.765625], f(x) = 0.5959472656249999
# Количество операций: 18
# Отклонение +-0.5959472656249999
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[0.5, 1], array([-0.125,  0.875]), array([0.03125 , 0.765625]), array([-0.0078125 ,  0.66992188]), array([0.00195313, 0.58618164])], e = 1e-05, e_1 = 0.9, e_2 = 0.15, M = 10
# Минимум алгоритма в x = [0.00195313 0.58618164], f(x) = 0.3436470627784729
# Количество операций: 30
# Отклонение +-0.3436470627784729
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[0.5, 1], array([-0.125,  0.875]), array([0.03125 , 0.765625]), array([-0.0078125 ,  0.66992188]), array([0.00195313, 0.58618164])], e = 1e-05, e_1 = 0.9, e_2 = 0.15, M = 2
# Минимум алгоритма в x = [0.03125  0.765625], f(x) = 0.5959472656249999
# Количество операций: 18
# Отклонение +-0.5959472656249999
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[0.5, 1], array([-0.125,  0.875]), array([0.03125 , 0.765625]), array([-0.0078125 ,  0.66992188]), array([0.00195313, 0.58618164])], e = 1e-05, e_1 = 0.9, e_2 = 0.9, M = 10
# Минимум алгоритма в x = [-0.0078125   0.66992188], f(x) = 0.4494056701660156
# Количество операций: 24
# Отклонение +-0.4494056701660156
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[0.5, 1], array([-0.125,  0.875]), array([0.03125 , 0.765625]), array([-0.0078125 ,  0.66992188]), array([0.00195313, 0.58618164])], e = 1e-05, e_1 = 0.9, e_2 = 0.9, M = 2
# Минимум алгоритма в x = [0.03125  0.765625], f(x) = 0.5959472656249999
# Количество операций: 18
# Отклонение +-0.5959472656249999
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[20, 40]], e = 0.1, e_1 = 0.1, e_2 = 0.15, M = 10
# Минимум алгоритма в x = [1.90734863e-05 1.05230230e+01], f(x) = 110.73401404192659
# Количество операций: 66
# Отклонение +-110.73401404192659
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[20, 40], array([-5., 35.]), array([ 1.25 , 30.625]), array([-0.3125  , 26.796875]), array([ 0.078125  , 23.44726563]), array([-1.95312500e-02,  2.05163574e+01]), array([4.88281250e-03, 1.79518127e+01]), array([-1.22070313e-03,  1.57078362e+01]), array([3.05175781e-04, 1.37443566e+01]), array([-7.62939453e-05,  1.20263121e+01]), array([1.90734863e-05, 1.05230230e+01])], e = 0.1, e_1 = 0.1, e_2 = 0.15, M = 2
# Минимум алгоритма в x = [ 1.25  30.625], f(x) = 953.5156250000009
# Количество операций: 18
# Отклонение +-953.5156250000009
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[20, 40], array([-5., 35.]), array([ 1.25 , 30.625]), array([-0.3125  , 26.796875]), array([ 0.078125  , 23.44726563]), array([-1.95312500e-02,  2.05163574e+01]), array([4.88281250e-03, 1.79518127e+01]), array([-1.22070313e-03,  1.57078362e+01]), array([3.05175781e-04, 1.37443566e+01]), array([-7.62939453e-05,  1.20263121e+01]), array([1.90734863e-05, 1.05230230e+01])], e = 0.1, e_1 = 0.1, e_2 = 0.9, M = 10
# Минимум алгоритма в x = [1.90734863e-05 1.05230230e+01], f(x) = 110.73401404192659
# Количество операций: 66
# Отклонение +-110.73401404192659
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[20, 40], array([-5., 35.]), array([ 1.25 , 30.625]), array([-0.3125  , 26.796875]), array([ 0.078125  , 23.44726563]), array([-1.95312500e-02,  2.05163574e+01]), array([4.88281250e-03, 1.79518127e+01]), array([-1.22070313e-03,  1.57078362e+01]), array([3.05175781e-04, 1.37443566e+01]), array([-7.62939453e-05,  1.20263121e+01]), array([1.90734863e-05, 1.05230230e+01])], e = 0.1, e_1 = 0.1, e_2 = 0.9, M = 2
# Минимум алгоритма в x = [ 1.25  30.625], f(x) = 953.5156250000009
# Количество операций: 18
# Отклонение +-953.5156250000009
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[20, 40], array([-5., 35.]), array([ 1.25 , 30.625]), array([-0.3125  , 26.796875]), array([ 0.078125  , 23.44726563]), array([-1.95312500e-02,  2.05163574e+01]), array([4.88281250e-03, 1.79518127e+01]), array([-1.22070313e-03,  1.57078362e+01]), array([3.05175781e-04, 1.37443566e+01]), array([-7.62939453e-05,  1.20263121e+01]), array([1.90734863e-05, 1.05230230e+01])], e = 0.1, e_1 = 0.9, e_2 = 0.15, M = 10
# Минимум алгоритма в x = [1.90734863e-05 1.05230230e+01], f(x) = 110.73401404192659
# Количество операций: 66
# Отклонение +-110.73401404192659
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[20, 40], array([-5., 35.]), array([ 1.25 , 30.625]), array([-0.3125  , 26.796875]), array([ 0.078125  , 23.44726563]), array([-1.95312500e-02,  2.05163574e+01]), array([4.88281250e-03, 1.79518127e+01]), array([-1.22070313e-03,  1.57078362e+01]), array([3.05175781e-04, 1.37443566e+01]), array([-7.62939453e-05,  1.20263121e+01]), array([1.90734863e-05, 1.05230230e+01])], e = 0.1, e_1 = 0.9, e_2 = 0.15, M = 2
# Минимум алгоритма в x = [ 1.25  30.625], f(x) = 953.5156250000009
# Количество операций: 18
# Отклонение +-953.5156250000009
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[20, 40], array([-5., 35.]), array([ 1.25 , 30.625]), array([-0.3125  , 26.796875]), array([ 0.078125  , 23.44726563]), array([-1.95312500e-02,  2.05163574e+01]), array([4.88281250e-03, 1.79518127e+01]), array([-1.22070313e-03,  1.57078362e+01]), array([3.05175781e-04, 1.37443566e+01]), array([-7.62939453e-05,  1.20263121e+01]), array([1.90734863e-05, 1.05230230e+01])], e = 0.1, e_1 = 0.9, e_2 = 0.9, M = 10
# Минимум алгоритма в x = [1.90734863e-05 1.05230230e+01], f(x) = 110.73401404192659
# Количество операций: 66
# Отклонение +-110.73401404192659
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[20, 40], array([-5., 35.]), array([ 1.25 , 30.625]), array([-0.3125  , 26.796875]), array([ 0.078125  , 23.44726563]), array([-1.95312500e-02,  2.05163574e+01]), array([4.88281250e-03, 1.79518127e+01]), array([-1.22070313e-03,  1.57078362e+01]), array([3.05175781e-04, 1.37443566e+01]), array([-7.62939453e-05,  1.20263121e+01]), array([1.90734863e-05, 1.05230230e+01])], e = 0.1, e_1 = 0.9, e_2 = 0.9, M = 2
# Минимум алгоритма в x = [ 1.25  30.625], f(x) = 953.5156250000009
# Количество операций: 18
# Отклонение +-953.5156250000009
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[20, 40], array([-5., 35.]), array([ 1.25 , 30.625]), array([-0.3125  , 26.796875]), array([ 0.078125  , 23.44726563]), array([-1.95312500e-02,  2.05163574e+01]), array([4.88281250e-03, 1.79518127e+01]), array([-1.22070313e-03,  1.57078362e+01]), array([3.05175781e-04, 1.37443566e+01]), array([-7.62939453e-05,  1.20263121e+01]), array([1.90734863e-05, 1.05230230e+01])], e = 1e-05, e_1 = 0.1, e_2 = 0.15, M = 10
# Минимум алгоритма в x = [1.90734863e-05 1.05230230e+01], f(x) = 110.73401404192659
# Количество операций: 66
# Отклонение +-110.73401404192659
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[20, 40], array([-5., 35.]), array([ 1.25 , 30.625]), array([-0.3125  , 26.796875]), array([ 0.078125  , 23.44726563]), array([-1.95312500e-02,  2.05163574e+01]), array([4.88281250e-03, 1.79518127e+01]), array([-1.22070313e-03,  1.57078362e+01]), array([3.05175781e-04, 1.37443566e+01]), array([-7.62939453e-05,  1.20263121e+01]), array([1.90734863e-05, 1.05230230e+01])], e = 1e-05, e_1 = 0.1, e_2 = 0.15, M = 2
# Минимум алгоритма в x = [ 1.25  30.625], f(x) = 953.5156250000009
# Количество операций: 18
# Отклонение +-953.5156250000009
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[20, 40], array([-5., 35.]), array([ 1.25 , 30.625]), array([-0.3125  , 26.796875]), array([ 0.078125  , 23.44726563]), array([-1.95312500e-02,  2.05163574e+01]), array([4.88281250e-03, 1.79518127e+01]), array([-1.22070313e-03,  1.57078362e+01]), array([3.05175781e-04, 1.37443566e+01]), array([-7.62939453e-05,  1.20263121e+01]), array([1.90734863e-05, 1.05230230e+01])], e = 1e-05, e_1 = 0.1, e_2 = 0.9, M = 10
# Минимум алгоритма в x = [1.90734863e-05 1.05230230e+01], f(x) = 110.73401404192659
# Количество операций: 66
# Отклонение +-110.73401404192659
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[20, 40], array([-5., 35.]), array([ 1.25 , 30.625]), array([-0.3125  , 26.796875]), array([ 0.078125  , 23.44726563]), array([-1.95312500e-02,  2.05163574e+01]), array([4.88281250e-03, 1.79518127e+01]), array([-1.22070313e-03,  1.57078362e+01]), array([3.05175781e-04, 1.37443566e+01]), array([-7.62939453e-05,  1.20263121e+01]), array([1.90734863e-05, 1.05230230e+01])], e = 1e-05, e_1 = 0.1, e_2 = 0.9, M = 2
# Минимум алгоритма в x = [ 1.25  30.625], f(x) = 953.5156250000009
# Количество операций: 18
# Отклонение +-953.5156250000009
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[20, 40], array([-5., 35.]), array([ 1.25 , 30.625]), array([-0.3125  , 26.796875]), array([ 0.078125  , 23.44726563]), array([-1.95312500e-02,  2.05163574e+01]), array([4.88281250e-03, 1.79518127e+01]), array([-1.22070313e-03,  1.57078362e+01]), array([3.05175781e-04, 1.37443566e+01]), array([-7.62939453e-05,  1.20263121e+01]), array([1.90734863e-05, 1.05230230e+01])], e = 1e-05, e_1 = 0.9, e_2 = 0.15, M = 10
# Минимум алгоритма в x = [1.90734863e-05 1.05230230e+01], f(x) = 110.73401404192659
# Количество операций: 66
# Отклонение +-110.73401404192659
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[20, 40], array([-5., 35.]), array([ 1.25 , 30.625]), array([-0.3125  , 26.796875]), array([ 0.078125  , 23.44726563]), array([-1.95312500e-02,  2.05163574e+01]), array([4.88281250e-03, 1.79518127e+01]), array([-1.22070313e-03,  1.57078362e+01]), array([3.05175781e-04, 1.37443566e+01]), array([-7.62939453e-05,  1.20263121e+01]), array([1.90734863e-05, 1.05230230e+01])], e = 1e-05, e_1 = 0.9, e_2 = 0.15, M = 2
# Минимум алгоритма в x = [ 1.25  30.625], f(x) = 953.5156250000009
# Количество операций: 18
# Отклонение +-953.5156250000009
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[20, 40], array([-5., 35.]), array([ 1.25 , 30.625]), array([-0.3125  , 26.796875]), array([ 0.078125  , 23.44726563]), array([-1.95312500e-02,  2.05163574e+01]), array([4.88281250e-03, 1.79518127e+01]), array([-1.22070313e-03,  1.57078362e+01]), array([3.05175781e-04, 1.37443566e+01]), array([-7.62939453e-05,  1.20263121e+01]), array([1.90734863e-05, 1.05230230e+01])], e = 1e-05, e_1 = 0.9, e_2 = 0.9, M = 10
# Минимум алгоритма в x = [1.90734863e-05 1.05230230e+01], f(x) = 110.73401404192659
# Количество операций: 66
# Отклонение +-110.73401404192659
#
# Истинный минимум в x = (0, 0), f(x) = 0
# При параметрах x_0 = [[20, 40], array([-5., 35.]), array([ 1.25 , 30.625]), array([-0.3125  , 26.796875]), array([ 0.078125  , 23.44726563]), array([-1.95312500e-02,  2.05163574e+01]), array([4.88281250e-03, 1.79518127e+01]), array([-1.22070313e-03,  1.57078362e+01]), array([3.05175781e-04, 1.37443566e+01]), array([-7.62939453e-05,  1.20263121e+01]), array([1.90734863e-05, 1.05230230e+01])], e = 1e-05, e_1 = 0.9, e_2 = 0.9, M = 2
# Минимум алгоритма в x = [ 1.25  30.625], f(x) = 953.5156250000009
# Количество операций: 18
# Отклонение +-953.5156250000009
